# %% [markdown]
# <a href="https://colab.research.google.com/github/Demidkov/SQL-HeadHunter/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Project_2_%D0%9D%D0%BE%D1%83%D1%82%D0%B1%D1%83%D0%BA_%D1%88%D0%B0%D0%B1%D0%BB%D0%BE%D0%BD_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий из HeadHunter

# %%
import pandas as pd
import psycopg2
import warnings
warnings.filterwarnings("ignore")

# %%
connection = psycopg2.connect(
  dbname = DBNAME,
  user = USER,
  password = PASSWORD,
  host = HOST,
  port  = PORT
)

# %% [markdown]
# # Юнит 3. Предварительный анализ данных

# %% [markdown]
# 1. Напишите запрос, который посчитает количество вакансий в нашей базе (вакансии находятся в таблице vacancies).

# %%
query = f'''select *
           from vacancies
        '''
df = pd.read_sql_query(query, connection)
# Out:
# <ipython-input-4-2e4a05ce0a0e>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
print('Number of vacancies :',df.shape[0])
# Out:
# Number of vacancies : 49197

# %% [markdown]
# 2. Напишите запрос, который посчитает количество работодателей (таблица employers).

# %%
query = f'''select *
           from employers
        '''
df = pd.read_sql_query(query, connection)
# Out:
# <ipython-input-9-e187906491b8>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
print('Number of employers :',df.shape[0])
# Out:
# Number of employers : 23501

# %% [markdown]
# 3. Посчитате с помощью запроса количество регионов (таблица areas).

# %%
query = f'''select *
           from areas
        '''
df = pd.read_sql_query(query, connection)
# Out:
# <ipython-input-12-4e88c64526ff>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
print('Number of areas :',df.shape[0])
# Out:
# Number of areas : 1362

# %% [markdown]
# 4. Посчитате с помощью запроса количество сфер деятельности в базе (таблица industries).

# %%
query = f'''select *
           from INDUSTRIES
        '''
df = pd.read_sql_query(query, connection)
# Out:
# <ipython-input-14-a6f593fb8890>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
print('Number of INDUSTRIES :',df.shape[0])
# Out:
# Number of INDUSTRIES : 294

# %% [markdown]
# ***

# %%
# выводы по предварительному анализу данных
'''
  Вывод: в базе данных Head Hunter существует огромное число вакансий (49197)
  от 23501 работодателей
  в 1362 регионах и
  в 294 отраслях
  то есть где бы Вы ни находились, можно найти вакансии, которые могут вас устроить.
'''
# Out:
# '\n  Вывод: в базе данных Head Hunter существует огромное число вакансий (49197) \n  от 23501 работодателей \n  в 1362 регионах и \n  в 294 отраслях\n  то есть где бы Вы ни находились, можно найти вакансии, которые могут вас устроить.\n'

# %% [markdown]
# # Юнит 4. Детальный анализ вакансий

# %% [markdown]
# 1. Напишите запрос, который позволит узнать, сколько (cnt) вакансий в каждом регионе (area).
# Отсортируйте по количеству вакансий в порядке убывания.

# %%
query = f'''
          select a.name area, count(v.name) cnt
          from areas a
          join vacancies v on a.id = v.area_id
          group by area
          order by cnt desc
          limit 5
        '''
df = pd.read_sql_query(query, connection)
# Out:
# <ipython-input-4-8d5ee1bac64c>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
df
# Out:
#               area   cnt
# 0           Москва  5333
# 1  Санкт-Петербург  2851
# 2            Минск  2112
# 3      Новосибирск  2006
# 4           Алматы  1892

# %% [markdown]
# 2. Напишите запрос, чтобы определить у какого количества вакансий заполнено хотя бы одно из двух полей с зарплатой.

# %%
query = f'''
          select DISTINCT v.schedule schedule, v.employment, count(v.employment)
          from vacancies v
          where (v.salary_from IS NOT NULL) OR (v.salary_to IS NOT NULL)
          --join vacancies v on a.id = v.area_id
          group by schedule, employment
          order by 3 desc
          --limit 5
        '''

# %%
df = pd.read_sql_query(query, connection)
df
# Out:
# <ipython-input-17-a4f003e08cb9>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#             schedule           employment  count
# 0        Полный день     Полная занятость  16848
# 1   Удаленная работа     Полная занятость   3713
# 2   Удаленная работа  Частичная занятость    923
# 3     Сменный график     Полная занятость    715
# 4      Гибкий график     Полная занятость    650
# 5     Вахтовый метод     Полная занятость    269
# 6        Полный день           Стажировка    264
# 7        Полный день  Частичная занятость    192
# 8      Гибкий график  Частичная занятость    148
# 9     Сменный график  Частичная занятость     97
# 10  Удаленная работа     Проектная работа     85
# 11       Полный день     Проектная работа     73
# 12     Гибкий график           Стажировка     51
# 13  Удаленная работа           Стажировка     31
# 14    Сменный график           Стажировка      8
# 15     Гибкий график     Проектная работа      4
# 16    Вахтовый метод     Проектная работа      1
# 17    Сменный график     Проектная работа      1

# %% [markdown]
# 3. Найдите средние значения для нижней и верхней границы зарплатной вилки. Округлите значения до целого.

# %%
query = f'''
          select DISTINCT *--v.schedule schedule, v.employment, count(v.employment)
          from vacancies v
          --where (v.salary_from IS NOT NULL) OR (v.salary_to IS NOT NULL)
          --join vacancies v on a.id = v.area_id
          --group by schedule, employment
          --order by 1,2
          --limit 5
        '''
df = pd.read_sql_query(query, connection)
# print(query)
# display(df)
#ss = df['schedule'].unique()
#for i in ss:
#  print(i, df['employment'].count())
#print(df['schedule'].unique(), df['employment'].unique())
#print(df.shape[0])
# Out:
# <ipython-input-18-6be32010d80c>:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
print('Средняя величина нижней планки зарплаты: ', round(df['salary_from'].mean()))
print('Средняя величина верхней планки зарплаты: ',round(df['salary_to'  ].mean()))
# Out:
# Средняя величина нижней планки зарплаты:  71065
# Средняя величина верхней планки зарплаты:  110537

# %% [markdown]
# 4. Напишите запрос, который выведет количество вакансий для каждого сочетания типа рабочего графика (schedule) и типа трудоустройства (employment), используемого в вакансиях. Результат отсортируйте по убыванию количества.

# %%
query = f'''
          select v.schedule schedule, v.employment, count(v.id)
          from vacancies v
          --where (v.salary_from IS NOT NULL) OR (v.salary_to IS NOT NULL)
          --join vacancies v on a.id = v.area_id
          group by schedule, employment
          order by 3 DESC
         limit 2
        '''
df = pd.read_sql_query(query, connection)
# print(query)
# display(df)
#print(df.shape[0])
# Out:
# <ipython-input-20-c69fe3a3f753>:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
print('На втором месте стоит: ',df['schedule'][1], df['employment'][1])
# Out:
# На втором месте стоит:  Удаленная работа Полная занятость

# %% [markdown]
# 5. Напишите запрос, выводящий значения поля Требуемый опыт работы (experience) в порядке возрастания количества вакансий, в которых указан данный вариант опыта.

# %%
query = f'''
          select v.experience, count(v.id)
          from vacancies v
          --where (v.salary_from IS NOT NULL) OR (v.salary_to IS NOT NULL)
          --join vacancies v on a.id = v.area_id
          group by experience
          order by 2
         --limit 2
        '''
df = pd.read_sql_query(query, connection)
# print(query)

#print(df.shape[0])
# Out:
# <ipython-input-22-b6e5fc62c46f>:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
display(df)
# Out:
#            experience  count
# 0         Более 6 лет   1337
# 1           Нет опыта   7197
# 2       От 3 до 6 лет  14511
# 3  От 1 года до 3 лет  26152

# %% [markdown]
# ***

# %%
# выводы по детальному анализу вакансий
'''
  Совершенно логично, наибольшее число вакансий зависит в первую очередь от того, сколько жителей в каждом регионе,
  при этом работодатели в основном хотят получать специалистов на полный рабочий день, можно и на удаленной работе
  Средняя зарплата при этом предлагается на уровне, близком к 100 тыс рублей (хотелось бы выше, конечно...)
  Чаще всего в требованих к соискателям стоит опыт работы от 1 года до 3 лет.
'''
# Out:
# '\n  Совершенно логично, наибольшее число вакансий зависит в первую очередь от того, сколько жителей в каждом регионе,\n  при этом работодатели в основном хотят получать специалистов на полный рабочий день, можно и на удаленной работе \n'

# %% [markdown]
# # Юнит 5. Анализ работодателей

# %% [markdown]
# 1. Напишите запрос, который позволит узнать, какие работодатели находятся на первом и пятом месте по количеству вакансий.

# %%
# текст запроса
query = f'''
          select e.name company,  count(v.id)
          from vacancies v
          --where (v.salary_from IS NOT NULL) OR (v.salary_to IS NOT NULL)
          join employers e on v.employer_id = e.id
          group by company
          order by 2 DESC
          limit 6
        '''
df = pd.read_sql_query(query, connection)
# print(query)
display(df)
# Out:
#          company  count
# 0         Яндекс   1933
# 1     Ростелеком    491
# 2       Тинькофф    444
# 3           СБЕР    428
# 4  Газпром нефть    331
# 5    ИК СИБИНТЕК    327

# %%
# результат запроса
print('Компании на первом и пятом местах: ',list(df['company'])[0], 'и ',list(df['company'])[4])
# Out:
# Компании на первом и пятом местах:  Яндекс и  Газпром нефть

# %% [markdown]
# 2. Напишите запрос, который для каждого региона выведет количество работодателей и вакансий в нём.
# Среди регионов, в которых нет вакансий, найдите тот, в котором наибольшее количество работодателей.

# %%
# текст запроса
query = f'''
          select a.name area, count(DISTINCT v.id) vacation, count(distinct e.id) company
          from areas a
          left join vacancies v on a.id = v.area_id
          left join employers e on a.id = e.area
          where v.area_id is null

          --where e.name IS NULL
          group by a.name
          --having count(v.name)=0 -- OR (v.salary_to IS NOT NULL)
          order by  3 desc
          --limit 6
        '''

# %%
df = pd.read_sql_query(query, connection)
# print(query)
display(df)
# Out:
#                                area  vacation  company
# 0                            Россия         0      410
# 1                         Казахстан         0      207
# 2                Московская область         0       75
# 3                Краснодарский край         0       19
# 4                          Беларусь         0       18
# ..                              ...       ...      ...
# 588                        Кувандык         0        0
# 589                        Куйбышев         0        0
# 590  Куйбышево (Ростовская область)         0        0
# 591                        Култаево         0        0
# 592                        Кульсары         0        0
#
# [593 rows x 3 columns]

# %% [markdown]
# 3. Для каждого работодателя посчитайте количество регионов, в которых он публикует свои вакансии. Отсортируйте результат по убыванию количества.

# %%
# текст запроса
query = f'''
          select e.name "Название компании", count(DISTINCT v.area_id) "Число регионов"--company, count(v.name) "Количество вакансий"-- vacancie
          from employers e
          --from vacancies v
          join vacancies v on e.id = v.employer_id
          --join areas a on v.area_id = a.id

          --where v.salary_to IS NULL

          group by e.name
          --having count(v.name)=0 -- OR (v.salary_to IS NOT NULL)
          order by 2 desc
          --limit 6
        '''

# %%
df = pd.read_sql_query(query, connection)
# print(query)
display(df)
# Out:
# <ipython-input-92-dd61089034fe>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#             Название компании  Число регионов
# 0                      Яндекс             181
# 1                  Ростелеком             152
# 2                  Спецремонт             116
# 3      Поляков Денис Иванович              88
# 4                   ООО ЕФИН               71
# ...                       ...             ...
# 14761                  UniSol               1
# 14762            UNISTORY LLC               1
# 14763                   UNIT6               1
# 14764     United Distribution               1
# 14765              UNITEL LLC               1
#
# [14766 rows x 2 columns]

# %% [markdown]
# 4. Напишите запрос для подсчёта количества работодателей, у которых не указана сфера деятельности.

# %%
query = f'''
          select *--a.name area, count(DISTINCT v.id) vacation, count(distinct e.id) company
          from employers e
          --from employers_industries ei
          left join employers_industries ei on e.id = ei.employer_id
          --left join employers e on a.id = e.area
          where ei.employer_id is null

          --where e.name IS NULL
          --group by a.name
          --having count(v.name)=0 -- OR (v.salary_to IS NOT NULL)
          order by  1 desc
          --limit 6
        '''
df = pd.read_sql_query(query, connection)
# print(query)
display(df)
print(f'Не указали сферу деятельности {df.shape[0]} работодателей ')
# Out:
# <ipython-input-14-b6f7925e2fe7>:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#            id                               name  area employer_id industry_id
# 0     8906189              Ходыч Роман Сергеевич  1955        None        None
# 1     8905803                         Ультра 100  1512        None        None
# 2     8904282   Центр Цифровых Технологий - МФТИ     1        None        None
# 3     8903831                        EasyDrive24    24        None        None
# 4     8903436  Kiber One, школа программирования    51        None        None
# ...       ...                                ...   ...         ...         ...
# 8414     3204                             ГК ТСС     1        None        None
# 8415     2053                  ФПК Гарант-Инвест     1        None        None
# 8416     1811                           Упаковка     1        None        None
# 8417     1304                             Luxoft     1        None        None
# 8418      960                                ОМС     1        None        None
#
# [8419 rows x 5 columns]
# Не указали сферу деятельности 8419 работодателей

# %%
print(f'Не указали сферу деятельности {df.shape[0]} работодателей ')
# Out:
# Не указали сферу деятельности 8419 работодателей

# %% [markdown]
# 5. Напишите запрос, чтобы узнать название компании, находящейся на третьем месте в алфавитном списке (по названию) компаний, у которых указано четыре сферы деятельности.

# %%
query = f'''
          select e.name area, count(DISTINCT ei.industry_id) industries--, count(distinct e.id) company
          from employers e
          --from employers_industries ei
          left join employers_industries ei on e.id = ei.employer_id
          --left join employers e on a.id = e.area
          --where ei.employer_id is null

          --where e.name IS NULL
          group by e.name
          having count(DISTINCT ei.industry_id) = 4
          order by  1
          --limit 6
        '''
df = pd.read_sql_query(query, connection)
# print(query)
display(df)
# Out:
#                  area  industries
# 0        101 Интернет           4
# 1            21vek.by           4
# 2                2ГИС           4
# 3                  2К           4
# 4         4 пикселя +           4
# ...               ...         ...
# 1127            ЮРИОН           4
# 1128  ЮТИП Технологии           4
# 1129           ЯКласс           4
# 1130            ЯрНео           4
# 1131    Яшин&Партнёры           4
#
# [1132 rows x 2 columns]

# %%
print('На 3-м месте по алфавиту среди компаний указавших 4 вида дейятельности стоит :',list(df['area'])[2])
# Out:
# На 3-м месте по алфавиту среди компаний указавших 4 вида дейятельности стоит : 2ГИС

# %% [markdown]
# 6. С помощью запроса выясните, у какого количества работодателей в качестве сферы деятельности указана Разработка программного обеспечения.

# %%
query = f'''
          select *--e.name area, count(DISTINCT ei.industry_id) industries--, count(distinct e.id) company
          from employers e
          --from employers_industries ei
          left join employers_industries ei on e.id = ei.employer_id
          left join industries i on ei.industry_id = i.id
          where i.name = 'Разработка программного обеспечения'--) and (e.name IS NULL)
          --group by e.name
          --having count(DISTINCT ei.industry_id) = 4
          order by  1
          --limit 6
        '''
df = pd.read_sql_query(query, connection)
# print(query)
display(df)
# Out:
#            id                           name  area  employer_id industry_id  \
# 0          25  Deutsche Telekom IT Solutions     2           25       7.540
# 1         115               Ай-Теко (I-Teco)     1          115       7.540
# 2         139                            IBS     1          139       7.540
# 3         154                        Diasoft     1          154       7.540
# 4         172                       1C-Рарус     1          172       7.540
# ...       ...                            ...   ...          ...         ...
# 3548  8891186                      Skynet.kz   160      8891186       7.540
# 3549  8892103     Коваленко Сергей Андреевич    92      8892103       7.540
# 3550  8897248                      VoltoTech  2759      8897248       7.540
# 3551  8900115               SOFTWARE WIZARDS  2759      8900115       7.540
# 3552  8906438                      MergeUnit  2758      8906438       7.540
#
#          id                                 name
# 0     7.540  Разработка программного обеспечения
# 1     7.540  Разработка программного обеспечения
# 2     7.540  Разработка программного обеспечения
# 3     7.540  Разработка программного обеспечения
# 4     7.540  Разработка программного обеспечения
# ...     ...                                  ...
# 3548  7.540  Разработка программного обеспечения
# 3549  7.540  Разработка программного обеспечения
# 3550  7.540  Разработка программного обеспечения
# 3551  7.540  Разработка программного обеспечения
# 3552  7.540  Разработка программного обеспечения
#
# [3553 rows x 7 columns]

# %%
print(f'Разработка программного обеспечения указана у {df.shape[0]} работодателей ')
# Out:
# Разработка программного обеспечения указана у 3553 работодателей

# %% [markdown]
# 7. Для компании «Яндекс» выведите список регионов-миллионников, в которых представлены вакансии компании, вместе с количеством вакансий в этих регионах. Также добавьте строку Total с общим количеством вакансий компании. Результат отсортируйте по возрастанию количества.
#
# Список городов-милионников надо взять [отсюда](https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D1%80%D0%BE%D0%B4%D0%B0-%D0%BC%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%B5%D1%80%D1%8B_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8).
#
# Если возникнут трудности с этим задание посмотрите материалы модуля  PYTHON-17. Как получать данные из веб-источников и API.

# %%
'''
  Вытаскиваем список городов-миллионников России парсингом со страницы WikPedia
'''
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
# from pprint import pprint # Импортируем функцию pprint()
# import codecs
# сначала открываем страницу Wikipedia, проверяем статус
url = 'https://ru.wikipedia.org/wiki/Города-миллионеры_России' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
print(response.status_code, 'Значит, всё открылось нормально\n')
#print(response.text)
# дальше работа с содержимым страницы
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title.text,'\n')                        # Выводим текст из полученного тега, который содержится в атрибуте text
tabl = page.find("table", class_="standard")       # ищем на странице таблицу

town = []
tt = tabl.find("tbody") # в таблице выбираем тело таблицы
qq = tt.find_all("tr")  # в теле таблицы выбираем все ряды

for ss in qq:
  qqq = list(ss.find("a"))  # в каждом ряде находим тег "а", преобразуем его в список
  town.append(qqq[0])       # и добавляем содержимое к списку городов
town = town[1:]             # в первом ряду кусок от названия, отсекаем его
print(town)
# Out:
# 200 Значит, всё открылось нормально
#
# Города-миллионеры России — Википедия
#
# ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Казань', 'Нижний Новгород', 'Красноярск', 'Челябинск', 'Самара', 'Уфа', 'Ростов-на-Дону', 'Краснодар', 'Омск', 'Воронеж', 'Пермь', 'Волгоград']

# %%
# формируем запрос
# сипользую список городов миллионников, формирую строку str для Where с его помощью
# я выбрал такой способ формирования запроса, потому что для меня довольно очевидно,
# что городов миллионников по определению не так много.
# Второй вариант, который, вероятно, предполагался - в предыдущем блоке сохранить результат выборки
# городов миллионников в виде отдельного файла в формате SQL, и далее запрос с использованием
# SQL запроса, с фильтрацией по признаку is not null после присоединения соответствующей таблицы

# формируем начало запроса
query = f'''
          (select a.name area, count(v.id) count -- count(DISTINCT ei.industry_id) industries--, count(distinct e.id) company
          from employers e
          join vacancies v on e.id = v.employer_id
          join areas a on v.area_id = a.id
          where (e.name = 'Яндекс')'''
# далее формируем строку для фильтрации городов миллионников из предыдущего блока
# в результате которого получили список городов миллионников
ll = len(town)
if ll > 0:
  str = f" AND (( a.name = '{town[0]}')" # если есть хоть один город миллионник
  if ll > 1:
    for s in town[1:]:
      str += f" OR (a.name = '{s}')"     # и для каждого следующего города из списка
print(str)                               # контролируем
                                         # далее завершение запроса
query += (str + f''')
          group by a.name
          order by  2 desc)
          '''
          +                             # далее суммирем результат
'''
          --limit 6
          union  all
          select 'Total :' area, count( v.id)
          from employers e
          join vacancies v on e.id = v.employer_id
          join areas a on v.area_id = a.id
          where (e.name = 'Яндекс')'''
          +str
          +
'''       )
          group by area
          order by  2
'''
)
print(query)
# Out:
#  AND (( a.name = 'Москва') OR (a.name = 'Санкт-Петербург') OR (a.name = 'Новосибирск') OR (a.name = 'Екатеринбург') OR (a.name = 'Казань') OR (a.name = 'Нижний Новгород') OR (a.name = 'Красноярск') OR (a.name = 'Челябинск') OR (a.name = 'Самара') OR (a.name = 'Уфа') OR (a.name = 'Ростов-на-Дону') OR (a.name = 'Краснодар') OR (a.name = 'Омск') OR (a.name = 'Воронеж') OR (a.name = 'Пермь') OR (a.name = 'Волгоград')
#
#           (select a.name area, count(v.id) count -- count(DISTINCT ei.industry_id) industries--, count(distinct e.id) company
#           from employers e
#           join vacancies v on e.id = v.employer_id
#           join areas a on v.area_id = a.id
#           where (e.name = 'Яндекс') AND (( a.name = 'Москва') OR (a.name = 'Санкт-Петербург') OR (a.name = 'Новосибирск') OR (a.name = 'Екатеринбург') OR (a.name = 'Казань') OR (a.name = 'Нижний Новгород') OR (a.name = 'Красноярск') OR (a.name = 'Челябинск') OR (a.name = 'Самара') OR (a.name = 'Уфа') OR (a.name = 'Ростов-на-Дону') OR (a.name = 'Краснодар') OR (a.name = 'Омск') OR (a.name = 'Воронеж') OR (a.name = 'Пермь') OR (a.name = 'Волгоград'))
#           group by a.name
#           order by  2 desc)
#
#           --limit 6
#           union  all
#           select 'Total :' area, count( v.id)
#           from employers e
#           join vacancies v on e.id = v.employer_id
#           join areas a on v.area_id = a.id
#           where (e.name = 'Яндекс') AND (( a.name = 'Москва') OR (a.name = 'Санкт-Петербург') OR (a.name = 'Новосибирск') OR (a.name = 'Екатеринбург') OR (a.name = 'Казань') OR (a.name = 'Нижний Новгород') OR (a.name = 'Красноярск') OR (a.name = 'Челябинск') OR (a.name = 'Самара') OR (a.name = 'Уфа') OR (a.name = 'Ростов-на-Дону') OR (a.name = 'Краснодар') OR (a.name = 'Омск') OR (a.name = 'Воронеж') OR (a.name = 'Пермь') OR (a.name = 'Волгоград')       )
#           group by area
#           order by  2

# %%
# результат запроса
df = pd.read_sql_query(query, connection)
display(df)
# Out:
# <ipython-input-11-89cf1ed82b3e>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                area  count
# 0              Омск     21
# 1         Челябинск     22
# 2        Красноярск     23
# 3         Волгоград     24
# 4            Казань     25
# 5    Ростов-на-Дону     25
# 6             Пермь     25
# 7            Самара     26
# 8               Уфа     26
# 9         Краснодар     30
# 10          Воронеж     32
# 11      Новосибирск     35
# 12  Нижний Новгород     36
# 13     Екатеринбург     39
# 14  Санкт-Петербург     42
# 15           Москва     54
# 16          Total :    485

# %%
# результат запроса

# %% [markdown]
# ***

# %%
# выводы по анализу работодателей
'''
Логично по количеству вакансий лидируют крупнейшие компании:
0 Яндекс	1933,
1	Ростелеком	491
2	Тинькофф	444
3	СБЕР	428
4	Газпром нефть	331
При этом крупнейшие компании предлагают вакансии в самых разных регионах,
в первую очередь в городах - миллионниках

'''

# %% [markdown]
# # Юнит 6. Предметный анализ

# %% [markdown]
# 1. Сколько вакансий имеет отношение к данным?
#
# Считаем, что вакансия имеет отношение к данным, если в её названии содержатся слова 'data' или 'данн'.
#
# *Подсказка: Обратите внимание, что названия вакансий могут быть написаны в любом регистре.*

# %%
# текст запроса
query = f'''
          select count(v.id)--, e.name--, v.name
          from vacancies v
          where  (v.name iLIKE '%data%') OR  (v.name iLIKE '%данн%')
          --AND (NOT (v.name  ilike '%junior%')  OR (v.employment ilike '%Стажировка%') OR (v.experience ilike '%Нет опыта%'))
          order by  1
        '''
df = pd.read_sql_query(query, connection)
#print(query, f'\n Всего найдено {df.shape[0]} вакансий, содержащих data или данн')
display(df)
# Out:
# <ipython-input-106-2ad624036485>:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    count
# 0   1771

# %%
# результат запроса

# %% [markdown]
# 2. Сколько есть подходящих вакансий для начинающего дата-сайентиста?
# Будем считать вакансиями для дата-сайентистов такие, в названии которых есть хотя бы одно из следующих сочетаний:
# * 'data scientist'
# * 'data science'
# * 'исследователь данных'
# * 'ML' (здесь не нужно брать вакансии по HTML)
# * 'machine learning'
# * 'машинн%обучен%'
#
# ** В следующих заданиях мы продолжим работать с вакансиями по этому условию.*
#
# Считаем вакансиями для специалистов уровня Junior следующие:
# * в названии есть слово 'junior' *или*
# * требуемый опыт — Нет опыта *или*
# * тип трудоустройства — Стажировка.

# %%
# текст запроса
query = f'''
select
    count(v.name)

from vacancies v

WHERE
(
    (name ILIKE '%data scientist%') OR (name ILIKE '%data science%') OR (name ILIKE '%исследователь данных%')
    OR ((name ILIKE '%ML%') AND (name NOT ILIKE '%HTML%'))
    OR (name ILIKE '%machine learning%')
    OR (name ILIKE '%машинн%обучен%')
    AND (key_skills IS NOT NULL)
)

    AND (v.name ILIKE '%junior%'
    OR v.experience ILIKE '%Нет опыта%'
    OR v.employment ILIKE '%Стажировка%')
        '''

df = pd.read_sql_query(query, connection)
#print(query, f'\n Всего найдено {df.shape[0]} вакансий, содержащих data или данн')
display(df)
# Out:
# <ipython-input-149-ad7f2acee9e7>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    count
# 0     51

# %%
# результат запроса

# %% [markdown]
# 3. Сколько есть вакансий для DS, в которых в качестве ключевого навыка указан SQL или postgres?
#
# ** Критерии для отнесения вакансии к DS указаны в предыдущем задании.*

# %%
# текст запроса
query = f'''
select --*
     v.id, v.key_skills
   --count(v.id)

from vacancies v

WHERE ( (v.key_skills like '%SQL%')
        or
        (v.key_skills ilike '%postgres%')
        )
    AND
(
    (name ILIKE '%data scientist%') OR (name ILIKE '%data science%') OR (name ILIKE '%исследователь данных%')
    OR ((name ILIKE '%ML%') AND (name NOT ILIKE '%HTML%'))
    OR (name ILIKE '%machine learning%')
    OR (name ILIKE '%машинн%обучен%')
    AND (key_skills IS NOT NULL)
)
  --AND (NOT (v.name  ilike '%junior%')  OR (v.employment ilike '%Стажировка%') OR (v.experience ilike '%Нет опыта%'))
    order by 1
    '''
df = pd.read_sql_query(query, connection)
print(df.shape[0]) # query, f'\n Всего найдено {df.shape[0]} вакансий, содержащих data или данн')
display(df)
# Out:
# <ipython-input-14-d638acdfd9e6>:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# 229
#            id                                         key_skills
# 0    48838707  Git\tSpring Framework\tJava\tPostgreSQL\tApach...
# 1    49930707  Linux\tPostgreSQL\tSQL\tPython\tJava\tPHP\tPer...
# 2    50533416          Python\tSQL\tРабота в команде\tOpenCV\tML
# 3    51001456          Python\tGit\tLinux\tSQL\tBig Data\tGolang
# 4    51834014  JavaScript\tMySQL\tОбучение и развитие\tУправл...
# ..        ...                                                ...
# 224  66134973  MS PowerPoint\tPython\tSQL\tПодготовка презент...
# 225  66142163  SQL\tMS SQL\tУдаленная работа\tPython\tМатемат...
# 226  66176514  Python\tJavaScript\tDjango Framework\tReact\tM...
# 227  66178607  Python\tPostgreSQL\tPyTorch\tTensorflow\tPanda...
# 228  66185427  Python\tLinux\tАнализ данных\tKeras\tData Scie...
#
# [229 rows x 2 columns]

# %%
# результат запроса

# %% [markdown]
# 4. Проверьте, насколько популярен Python в требованиях работодателей к DS.Для этого вычислите количество вакансий, в которых в качестве ключевого навыка указан Python.
#
# ** Это можно сделать помощью запроса, аналогичного предыдущему.*

# %%
# текст запроса
query = f'''select
    --DISTINCT
     v.id, v.key_skills
    -- count(v.name)

from vacancies v

WHERE
(v.key_skills ilike '%Python%')
AND
(   (name ILIKE '%data scientist%') OR (name ILIKE '%data science%') OR (name ILIKE '%исследователь данных%')
    OR ((name LIKE '%ML%') AND (name NOT ILIKE '%HTML%'))
    OR (name ILIKE '%machine learning%')
    OR (name ILIKE '%машинн%обучен%')
    AND (key_skills IS NOT NULL)
)
    '''
df = pd.read_sql_query(query, connection)
#print(query, f'\n Всего найдено {df.shape[0]} вакансий, содержащих data или данн')
display(df)
# Out:
#            id                                         key_skills
# 0    50533416          Python\tSQL\tРабота в команде\tOpenCV\tML
# 1    54824572  Oracle Pl/SQL\tБазы данных\tMachine Learning\t...
# 2    54825318  Python\tOpenCV\tTensorflow\tComputer Vision\tН...
# 3    66120847                     Python\tFlask\tLinux\tAWS\tGit
# 4    55351147   Python\tSQL\tNLP\tScikit-learn\tMachine Learning
# ..        ...                                                ...
# 346  55478561  Python\tLinux\tSQL\tPyTorch\tOpenCV\tKeras\tCa...
# 347  55306481  Python\tАналитическое мышление\tАнализ данных\...
# 348  54918116  Python\tNumpy\tPyTorch\tPandas\tМатематический...
# 349  55185186           Python\tScikit-learn\tPandas\tGit\tNumpy
# 350  55311099  Python\tLinux\tKubernetes\tAWS\tGit\tPeople Ma...
#
# [351 rows x 2 columns]

# %%
# результат запроса
print(f'Python используется в качестве ключевого навыка в\n{df.shape[0]} запросах')
# Out:
# Python используется в качестве ключевого навыка в
# 357 запросах

# %% [markdown]
# 5. Сколько ключевых навыков в среднем указывают в вакансиях для DS?
# Ответ округлите до двух знаков после точки-разделителя.

# %%
# текст запроса
query = f'''select
round(avg(length(key_skills) - length(replace(key_skills,CHR(9),''))+1),2)

from vacancies v

WHERE
(
       (v.name ILIKE '%data scientist%')
    OR (lower(v.name) ILIKE '%data science%')
    OR (v.name ILIKE '%исследователь данных%')
    OR (v.name  LIKE '%ML%' AND  (v.name NOT iLIKE '%html%'))
    OR (v.name ILIKE '%machine learning%')
    OR (v.name ILIKE '%машинн%обучен%')
    AND (key_skills IS NOT NULL)
)
    '''
df = pd.read_sql_query(query, connection)
#print(query, f'\n Всего найдено {df.shape[0]} вакансий, содержащих data или данн')
display(df)
# Out:
#    round
# 0   6.41

# %%
# Out:
#    round
# 0   6.41

# %% [markdown]
# 6. Напишите запрос, позволяющий вычислить, какую зарплату для DS в **среднем** указывают для каждого типа требуемого опыта (уникальное значение из поля *experience*).
#
# При решении задачи примите во внимание следующее:
# 1. Рассматриваем только вакансии, у которых заполнено хотя бы одно из двух полей с зарплатой.
# 2. Если заполнены оба поля с зарплатой, то считаем зарплату по каждой вакансии как сумму двух полей, делённую на 2. Если заполнено только одно из полей, то его и считаем зарплатой по вакансии.
# 3. Если в расчётах участвует null, в результате он тоже даст null (посмотрите, что возвращает запрос select 1 + null). Чтобы избежать этой ситуацию, мы воспользуемся функцией [coalesce](https://postgrespro.ru/docs/postgresql/9.5/functions-conditional#functions-coalesce-nvl-ifnull), которая заменит null на значение, которое мы передадим. Например, посмотрите, что возвращает запрос `select 1 + coalesce(null, 0)`
#
# Выясните, на какую зарплату в среднем может рассчитывать дата-сайентист с опытом работы от 3 до 6 лет. Результат округлите до целого числа.

# %%
# текст запроса
query = f'''select

  v.experience, ROUND(AVG(coalesce((v.salary_from + v.salary_to) / 2, v.salary_from, v.salary_to)), 0)

from vacancies v

WHERE
(
       (v.name ILIKE '%data scientist%')
    OR (lower(v.name) ILIKE '%data science%')
    OR (v.name ILIKE '%исследователь данных%')
    OR (v.name  LIKE '%ML%' AND  (v.name NOT iLIKE '%html%'))
    OR (v.name ILIKE '%machine learning%')
    OR (v.name ILIKE '%машинн%обучен%')
    AND (key_skills IS NOT NULL)
)

GROUP BY v.experience
ORDER BY 1
    '''
df = pd.read_sql_query(query, connection)
#print(query, f'\n Всего найдено {df.shape[0]} вакансий, содержащих data или данн')
display(df)
# Out:
#            experience     round
# 0         Более 6 лет       NaN
# 1           Нет опыта   74643.0
# 2  От 1 года до 3 лет  145236.0
# 3       От 3 до 6 лет  243115.0

# %%
# результат запроса

# %% [markdown]
# ***

# %%
# выводы по предметному анализу
'''
Среди большого разнообразия данных можно найти и вакансии по специальности Data Science
Многие специализации требуют знания Python и SQL
Специалистам с опытом от 3 до 6 лет предлагается в среднем зарплата более 240 тысяч,
с опытом от 1 года до 3 лет более 140 тысяч.
'''
# Out:
# '\nСреди большого разнообразия данных можно найти и вакансии по специальности Data Science \nМногие специализации требуют знания Python и SQL\nСпециалистам с опытом от 3 до 6 лет предлагается в среднем зарплата более 240 тысяч, \n'

# %% [markdown]
# # Общий вывод по проекту

# %%
# подведем итог исследования, обобщите выводы
# здесь можно (это будет плюсом) провести дополнительные исследования данных, сделать прогнозы, продумать варианты продолжения исследования
'''
Вывод: Компания Head Hunter даёт обширную базу данных по поиску работы для соискателей и
прекрасный ресурс для работодателей,
фактически компания стала ведущей в этой области не только в России,
но и на просторах соседних государств, для русскоязычных клиентов.
Это достигнуто за счет построения хорошо структурированной базы данных с
удобными сервисами как для работодателей,
так и для соискателей вакансий.

'''
# Out:
# '\nВывод: Компания Head Hunter даёт обширную базу данных по поиску работы для соискателей и \nпрекрасный ресурс для работодателей, и \nфактически компания стала ведущей в этой области не только в России, но и на просторах соседних государств, \nдля русскоязычных клиентов.\nЭто достигнуто за счет построения хорошо структурированной базы данных с удобными сервисами как для работодателей,\nтак и для соискателей вакансий.\n'
